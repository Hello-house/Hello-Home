# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from tqdm import tqdm_notebook
from random import *
from sklearn.neighbors import KNeighborsClassifier
import pickle
from sklearn.externals import joblib

# %%
data = pd.read_csv('dataset_interior.csv',index_col = 'index')

# %%
X = data.drop('style',axis=1)
y = data['style']

# %%
X_train_one_hot = pd.get_dummies(X)

# %%
X_train_one_hot
# Out:
#        q1  q2  q3  q4  q5  q6  q7  classic  profound  luxury  ...  \
# index                                                         ...
# 1       3   3   2   3   2   3   2        4         4       4  ...
# 2       5   5   3   4   4   3   2        3         3       4  ...
# 3       2   4   2   2   2   1   1        2         3       3  ...
# 4       5   5   3   5   3   4   2        2         3       4  ...
# 5       3   4   2   3   3   3   1        1         2       3  ...
# ...    ..  ..  ..  ..  ..  ..  ..      ...       ...     ...  ...
# 510     2   5   4   2   4   5   1        2         2       5  ...
# 511     4   3   3   3   3   3   4        2         4       2  ...
# 512     3   5   4   3   1   2   2        1         3       2  ...
# 513     2   3   4   4   1   2   3        3         1       4  ...
# 514     3   5   2   3   5   2   3        4         3       1  ...
#
#        color1_casual  color1_classic  color1_modern  color1_natural  \
# index
# ...

# %%
# !pip install xgboost

# %%
import xgboost
from xgboost import XGBClassifier

# %%
clf = xgboost.XGBClassifier(n_estimators=100, learning_rate = 0.1, max_depth=9,random_state=0)
clf.fit(X_train_one_hot,y)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#        importance_type='gain', interaction_constraints=None,
#        learning_rate=0.1, max_delta_step=0, max_depth=9,
#        min_child_weight=1, missing=nan, monotone_constraints=None,
#        n_estimators=100, n_jobs=0, num_parallel_tree=1,
#        objective='multi:softprob', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=None, subsample=1, tree_method=None,
#        validate_parameters=False, verbosity=None)

# %% [markdown]
# clf = KNeighborsClassifier(n_neighbors=3)
# clf.fit(X_train_one_hot,y)

# %%
saved_model = pickle.dumps(clf)

# %%
clf_from_pickle = pickle.loads(saved_model)

# %%
joblib.dump(clf,'homemodel1.pkl')
# Out:
# ['homemodel1.pkl']

# %%
clf_from_joblib = joblib.load('homemodel.pkl')
